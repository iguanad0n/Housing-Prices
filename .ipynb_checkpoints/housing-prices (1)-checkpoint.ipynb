# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from sklearn.impute import SimpleImputer
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/home-data-for-ml-course/sample_submission.csv
# /kaggle/input/home-data-for-ml-course/sample_submission.csv.gz
# /kaggle/input/home-data-for-ml-course/train.csv.gz
# /kaggle/input/home-data-for-ml-course/data_description.txt
# /kaggle/input/home-data-for-ml-course/test.csv.gz
# /kaggle/input/home-data-for-ml-course/train.csv
# /kaggle/input/home-data-for-ml-course/test.csv

# %% [markdown]
# # Получение данных

# %% [markdown]
# Загружаем обучающий и тестовый датасеты из файлов и выводим первые строки обучающего набора для ознакомления с данными.

# %%
train_data = pd.read_csv('../input/home-data-for-ml-course/train.csv', index_col=0)
test_data = pd.read_csv('../input/home-data-for-ml-course/test.csv', index_col=0)

train_data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# Просматриваем основную информацию о тренировочном датасете: типы столбцов, количество непустых значений и объем памяти.

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     588 non-null    object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %%
X = train_data.copy()

# %% [markdown]
# # Анализ данных

# %% [markdown]
# Выбираем все числовые столбцы из датасета для дальнейшего анализа.

# %%
num_col = X.select_dtypes(exclude=['object'])

# %% [markdown]
# Строим гистограммы распределения для всех числовых признаков, чтобы визуально оценить их распределение.

# %%
plt.figure(figsize=(16,18))

for i in range(len(num_col.columns)):
    plt.subplot(10, 4, i + 1)
    sns.histplot(num_col.iloc[:, i].dropna())
    plt.xticks(rotation=90)
    plt.ylabel('')
    
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# По гистограммам можем увидеть, что многие переменные имеют сильную ассиметрию

# %%
skew_features = X.select_dtypes(exclude=['object']).skew().sort_values(ascending=False)
skew_features = pd.DataFrame({'Skew' : skew_features})
skew_features.style.background_gradient('rocket_r')
# Out:
# <style type="text/css">
# #T_d392c_row0_col0 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_d392c_row1_col0 {
#   background-color: #9a1b5b;
#   color: #f1f1f1;
# }
# #T_d392c_row2_col0 {
#   background-color: #c71951;
#   color: #f1f1f1;
# }
# #T_d392c_row3_col0 {
#   background-color: #df2f44;
#   color: #f1f1f1;
# }
# #T_d392c_row4_col0 {
#   background-color: #eb463e;
#   color: #f1f1f1;
# }
# #T_d392c_row5_col0 {
#   background-color: #f69b71;
#   color: #000000;
# }
# #T_d392c_row6_col0 {
#   background-color: #f6a077;
#   color: #000000;
# }
# #T_d392c_row7_col0, #T_d392c_row8_col0 {
#   background-color: #f6a178;
#   color: #000000;
# }
# #T_d392c_row9_col0 {
#   background-color: #f6b18b;
#   color: #000000;
# }
# #T_d392c_row10_col0 {
#   background-color: #f6b995;
#   color: #000000;
# }
# #T_d392c_row11_col0 {
#   background-color: #f6be9b;
#   color: #000000;
# }
# #T_d392c_row12_col0 {
#   background-color: #f6c19f;
#   color: #000000;
# }
# #T_d392c_row13_col0 {
#   background-color: #f7c6a6;
#   color: #000000;
# }
# #T_d392c_row14_col0 {
#   background-color: #f7c9aa;
#   color: #000000;
# }
# #T_d392c_row15_col0, #T_d392c_row16_col0 {
#   background-color: #f7caac;
#   color: #000000;
# }
# #T_d392c_row17_col0, #T_d392c_row18_col0, #T_d392c_row19_col0 {
#   background-color: #f7cdb1;
#   color: #000000;
# }
# #T_d392c_row20_col0 {
#   background-color: #f8d4bc;
#   color: #000000;
# }
# #T_d392c_row21_col0 {
#   background-color: #f8d6be;
#   color: #000000;
# }
# #T_d392c_row22_col0, #T_d392c_row23_col0, #T_d392c_row24_col0, #T_d392c_row25_col0 {
#   background-color: #f8d7c0;
#   color: #000000;
# }
# #T_d392c_row26_col0 {
#   background-color: #f8d9c3;
#   color: #000000;
# }
# #T_d392c_row27_col0, #T_d392c_row28_col0, #T_d392c_row29_col0, #T_d392c_row30_col0 {
#   background-color: #f9dfcb;
#   color: #000000;
# }
# #T_d392c_row31_col0 {
#   background-color: #f9e0cd;
#   color: #000000;
# }
# #T_d392c_row32_col0 {
#   background-color: #f9e2d0;
#   color: #000000;
# }
# #T_d392c_row33_col0 {
#   background-color: #fae6d6;
#   color: #000000;
# }
# #T_d392c_row34_col0 {
#   background-color: #fae9da;
#   color: #000000;
# }
# #T_d392c_row35_col0, #T_d392c_row36_col0 {
#   background-color: #faebdd;
#   color: #000000;
# }
# </style>
# <table id="T_d392c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d392c_level0_col0" class="col_heading level0 col0" >Skew</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d392c_level0_row0" class="row_heading level0 row0" >MiscVal</th>
#       <td id="T_d392c_row0_col0" class="data row0 col0" >24.476794</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row1" class="row_heading level0 row1" >PoolArea</th>
#       <td id="T_d392c_row1_col0" class="data row1 col0" >14.828374</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row2" class="row_heading level0 row2" >LotArea</th>
#       <td id="T_d392c_row2_col0" class="data row2 col0" >12.207688</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row3" class="row_heading level0 row3" >3SsnPorch</th>
#       <td id="T_d392c_row3_col0" class="data row3 col0" >10.304342</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row4" class="row_heading level0 row4" >LowQualFinSF</th>
#       <td id="T_d392c_row4_col0" class="data row4 col0" >9.011341</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row5" class="row_heading level0 row5" >KitchenAbvGr</th>
#       <td id="T_d392c_row5_col0" class="data row5 col0" >4.488397</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row6" class="row_heading level0 row6" >BsmtFinSF2</th>
#       <td id="T_d392c_row6_col0" class="data row6 col0" >4.255261</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row7" class="row_heading level0 row7" >ScreenPorch</th>
#       <td id="T_d392c_row7_col0" class="data row7 col0" >4.122214</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row8" class="row_heading level0 row8" >BsmtHalfBath</th>
#       <td id="T_d392c_row8_col0" class="data row8 col0" >4.103403</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row9" class="row_heading level0 row9" >EnclosedPorch</th>
#       <td id="T_d392c_row9_col0" class="data row9 col0" >3.089872</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row10" class="row_heading level0 row10" >MasVnrArea</th>
#       <td id="T_d392c_row10_col0" class="data row10 col0" >2.669084</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row11" class="row_heading level0 row11" >OpenPorchSF</th>
#       <td id="T_d392c_row11_col0" class="data row11 col0" >2.364342</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row12" class="row_heading level0 row12" >LotFrontage</th>
#       <td id="T_d392c_row12_col0" class="data row12 col0" >2.163569</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row13" class="row_heading level0 row13" >SalePrice</th>
#       <td id="T_d392c_row13_col0" class="data row13 col0" >1.882876</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row14" class="row_heading level0 row14" >BsmtFinSF1</th>
#       <td id="T_d392c_row14_col0" class="data row14 col0" >1.685503</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row15" class="row_heading level0 row15" >WoodDeckSF</th>
#       <td id="T_d392c_row15_col0" class="data row15 col0" >1.541376</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row16" class="row_heading level0 row16" >TotalBsmtSF</th>
#       <td id="T_d392c_row16_col0" class="data row16 col0" >1.524255</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row17" class="row_heading level0 row17" >MSSubClass</th>
#       <td id="T_d392c_row17_col0" class="data row17 col0" >1.407657</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row18" class="row_heading level0 row18" >1stFlrSF</th>
#       <td id="T_d392c_row18_col0" class="data row18 col0" >1.376757</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row19" class="row_heading level0 row19" >GrLivArea</th>
#       <td id="T_d392c_row19_col0" class="data row19 col0" >1.366560</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row20" class="row_heading level0 row20" >BsmtUnfSF</th>
#       <td id="T_d392c_row20_col0" class="data row20 col0" >0.920268</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row21" class="row_heading level0 row21" >2ndFlrSF</th>
#       <td id="T_d392c_row21_col0" class="data row21 col0" >0.813030</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row22" class="row_heading level0 row22" >OverallCond</th>
#       <td id="T_d392c_row22_col0" class="data row22 col0" >0.693067</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row23" class="row_heading level0 row23" >TotRmsAbvGrd</th>
#       <td id="T_d392c_row23_col0" class="data row23 col0" >0.676341</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row24" class="row_heading level0 row24" >HalfBath</th>
#       <td id="T_d392c_row24_col0" class="data row24 col0" >0.675897</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row25" class="row_heading level0 row25" >Fireplaces</th>
#       <td id="T_d392c_row25_col0" class="data row25 col0" >0.649565</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row26" class="row_heading level0 row26" >BsmtFullBath</th>
#       <td id="T_d392c_row26_col0" class="data row26 col0" >0.596067</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row27" class="row_heading level0 row27" >OverallQual</th>
#       <td id="T_d392c_row27_col0" class="data row27 col0" >0.216944</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row28" class="row_heading level0 row28" >MoSold</th>
#       <td id="T_d392c_row28_col0" class="data row28 col0" >0.212053</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row29" class="row_heading level0 row29" >BedroomAbvGr</th>
#       <td id="T_d392c_row29_col0" class="data row29 col0" >0.211790</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row30" class="row_heading level0 row30" >GarageArea</th>
#       <td id="T_d392c_row30_col0" class="data row30 col0" >0.179981</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row31" class="row_heading level0 row31" >YrSold</th>
#       <td id="T_d392c_row31_col0" class="data row31 col0" >0.096269</td>
#     </tr>
#     <tr>
#       <th id="T_d392c_level0_row32" class="

# %% [markdown]
# Выбираем все категориальные столбцы из датасета для дальнейшей обработки.

# %%
cat_col = X.select_dtypes(include=['object'])

# %% [markdown]
# Строим графики количества для всех категориальных признаков, чтобы оценить распределение категорий.

# %%
plt.figure(figsize=(18,20))
for i in range(len(cat_col.columns)):
    plt.subplot(11,4,i+1)
    sns.countplot(x=cat_col.iloc[:, i], data=cat_col.dropna())
    plt.xticks(rotation=90)
    plt.ylabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Корреляция между числовыми переменными и ценой продажи

# %% [markdown]
# Строим диаграммы рассеяния числовых признаков и целевой переменной для оценки корреляции.

# %%
correlation = num_col.corr()
corr_price = correlation[['SalePrice']]

plt.figure(figsize=(17,20))
for i in range(len(num_col.columns)):
    plt.subplot(10,4,i+1)
    sns.scatterplot(x=num_col.iloc[:, i], y='SalePrice', data=num_col.dropna())
    plt.title('Corr to SalePrice = {}'.format(np.around(corr_price.iloc[i, 0], decimals=3)))
plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам корреляций фич и таргета можем увидеть, что некоторые из них имеют выбросы:
# - LotFrontage (>200)
# - LotArea (>100000)
# - BsmtFinSF1 (>3000)
# - TotalBsmtSF (>5000)
# - 1stFlrSF (>4000)
# - 2NDfLRsf (>4000)
# - GrLivArea (>4000 и SalePrice <300000)
# - LowQualFinSF (>550)

# %% [markdown]
# ## Корреляция между признаками

# %% [markdown]
# Визуализируем матрицу корреляций числовых признаков с помощью тепловой карты для выявления сильных взаимосвязей.

# %%
plt.figure(figsize=(20,20))
correlation = num_col.corr()
sns.heatmap(correlation, linewidth=1, cmap='rocket_r', annot=True, fmt='.2f', cbar=False, square=True)
plt.title("Correlation of numerical attributes", size=16)
plt.show()

# %%
col_corr_drop = {'GarageYrBlt', 'TotRmsAbvGrd', '1stFlrSF', 'GarageCars'}

# %% [markdown]
# По тепловой карте корреляций мы можем увидеть, что следующие признаки имею высокую корреляцию друг с другом:
# - Garage YrBlt и YearBuilt
# - TotRmsAbvGrd и GrLivArea
# - 1stFlrSF и TotalBsmtSF
# - GarageArea и GarageCars
# В дальнейшем эти признаки нужно будет удалить, чтобы избежать мультиколлинеарности.

# %% [markdown]
# ## Определение пропущенных значений

# %% [markdown]
# Функция для анализа пропущенных данных в датафрейме: показывает количество и процент пропусков по столбцам с визуальным выделением.

# %%
def missing_data(df):
    missing = df.isnull().sum().sort_values(ascending=False)
    total_missing = missing[missing != 0]
    percent_missing = np.around(((missing / len(df) * 100)[(missing / len(df) * 100) != 0]), decimals=2)
    return pd.concat([total_missing, percent_missing], axis=1, keys = ['Total', 'Percent'])

missing_data(X).style.background_gradient('rocket_r')
# Out:
# <style type="text/css">
# #T_789cb_row0_col0, #T_789cb_row0_col1 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_789cb_row1_col0, #T_789cb_row1_col1 {
#   background-color: #0d0a21;
#   color: #f1f1f1;
# }
# #T_789cb_row2_col0, #T_789cb_row2_col1 {
#   background-color: #160e27;
#   color: #f1f1f1;
# }
# #T_789cb_row3_col0, #T_789cb_row3_col1 {
#   background-color: #481c48;
#   color: #f1f1f1;
# }
# #T_789cb_row4_col0, #T_789cb_row4_col1 {
#   background-color: #a11a5b;
#   color: #f1f1f1;
# }
# #T_789cb_row5_col0, #T_789cb_row5_col1 {
#   background-color: #d3214b;
#   color: #f1f1f1;
# }
# #T_789cb_row6_col0, #T_789cb_row6_col1 {
#   background-color: #f6a67e;
#   color: #000000;
# }
# #T_789cb_row7_col0, #T_789cb_row7_col1, #T_789cb_row8_col0, #T_789cb_row8_col1, #T_789cb_row9_col0, #T_789cb_row9_col1, #T_789cb_row10_col0, #T_789cb_row10_col1, #T_789cb_row11_col0, #T_789cb_row11_col1 {
#   background-color: #f8d6be;
#   color: #000000;
# }
# #T_789cb_row12_col0, #T_789cb_row12_col1, #T_789cb_row13_col0, #T_789cb_row13_col1, #T_789cb_row14_col0, #T_789cb_row14_col1, #T_789cb_row15_col0, #T_789cb_row15_col1, #T_789cb_row16_col0, #T_789cb_row16_col1 {
#   background-color: #f9e2d0;
#   color: #000000;
# }
# #T_789cb_row17_col0, #T_789cb_row17_col1 {
#   background-color: #fae9da;
#   color: #000000;
# }
# #T_789cb_row18_col0, #T_789cb_row18_col1 {
#   background-color: #faebdd;
#   color: #000000;
# }
# </style>
# <table id="T_789cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_789cb_level0_col0" class="col_heading level0 col0" >Total</th>
#       <th id="T_789cb_level0_col1" class="col_heading level0 col1" >Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_789cb_level0_row0" class="row_heading level0 row0" >PoolQC</th>
#       <td id="T_789cb_row0_col0" class="data row0 col0" >1453</td>
#       <td id="T_789cb_row0_col1" class="data row0 col1" >99.520000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row1" class="row_heading level0 row1" >MiscFeature</th>
#       <td id="T_789cb_row1_col0" class="data row1 col0" >1406</td>
#       <td id="T_789cb_row1_col1" class="data row1 col1" >96.300000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row2" class="row_heading level0 row2" >Alley</th>
#       <td id="T_789cb_row2_col0" class="data row2 col0" >1369</td>
#       <td id="T_789cb_row2_col1" class="data row2 col1" >93.770000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row3" class="row_heading level0 row3" >Fence</th>
#       <td id="T_789cb_row3_col0" class="data row3 col0" >1179</td>
#       <td id="T_789cb_row3_col1" class="data row3 col1" >80.750000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row4" class="row_heading level0 row4" >MasVnrType</th>
#       <td id="T_789cb_row4_col0" class="data row4 col0" >872</td>
#       <td id="T_789cb_row4_col1" class="data row4 col1" >59.730000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row5" class="row_heading level0 row5" >FireplaceQu</th>
#       <td id="T_789cb_row5_col0" class="data row5 col0" >690</td>
#       <td id="T_789cb_row5_col1" class="data row5 col1" >47.260000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row6" class="row_heading level0 row6" >LotFrontage</th>
#       <td id="T_789cb_row6_col0" class="data row6 col0" >259</td>
#       <td id="T_789cb_row6_col1" class="data row6 col1" >17.740000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row7" class="row_heading level0 row7" >GarageYrBlt</th>
#       <td id="T_789cb_row7_col0" class="data row7 col0" >81</td>
#       <td id="T_789cb_row7_col1" class="data row7 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row8" class="row_heading level0 row8" >GarageCond</th>
#       <td id="T_789cb_row8_col0" class="data row8 col0" >81</td>
#       <td id="T_789cb_row8_col1" class="data row8 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row9" class="row_heading level0 row9" >GarageType</th>
#       <td id="T_789cb_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_789cb_row9_col1" class="data row9 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row10" class="row_heading level0 row10" >GarageFinish</th>
#       <td id="T_789cb_row10_col0" class="data row10 col0" >81</td>
#       <td id="T_789cb_row10_col1" class="data row10 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row11" class="row_heading level0 row11" >GarageQual</th>
#       <td id="T_789cb_row11_col0" class="data row11 col0" >81</td>
#       <td id="T_789cb_row11_col1" class="data row11 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row12" class="row_heading level0 row12" >BsmtExposure</th>
#       <td id="T_789cb_row12_col0" class="data row12 col0" >38</td>
#       <td id="T_789cb_row12_col1" class="data row12 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row13" class="row_heading level0 row13" >BsmtFinType2</th>
#       <td id="T_789cb_row13_col0" class="data row13 col0" >38</td>
#       <td id="T_789cb_row13_col1" class="data row13 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row14" class="row_heading level0 row14" >BsmtCond</th>
#       <td id="T_789cb_row14_col0" class="data row14 col0" >37</td>
#       <td id="T_789cb_row14_col1" class="data row14 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row15" class="row_heading level0 row15" >BsmtQual</th>
#       <td id="T_789cb_row15_col0" class="data row15 col0" >37</td>
#       <td id="T_789cb_row15_col1" class="data row15 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row16" class="row_heading level0 row16" >BsmtFinType1</th>
#       <td id="T_789cb_row16_col0" class="data row16 col0" >37</td>
#       <td id="T_789cb_row16_col1" class="data row16 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row17" class="row_heading level0 row17" >MasVnrArea</th>
#       <td id="T_789cb_row17_col0" class="data row17 col0" >8</td>
#       <td id="T_789cb_row17_col1" class="data row17 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_789cb_level0_row18" class="row_heading level0 row18" >Electrical</th>
#       <td id="T_789cb_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_789cb_row18_col1" class="data row18 col1" >0.070000</td>
#     </tr>
#   </tbody>
# </table>

# %%
col_missing_drop = {'PoolQC', 'MiscFeature', 'Alley'}

# %% [markdown]
# В столбцах 'PoolQC', 'MiscFeature' и 'Alley' слишком много пропущенных значений. В дальнейшим их необходимо удалить.

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# Удаляем выбросы из датасета.

# %%
X = X.drop(X[X['LotFrontage'] > 200].index)
X = X.drop(X[X['LotArea'] > 100000].index)
X = X.drop(X[X['BsmtFinSF1'] > 4000].index)
X = X.drop(X[X['TotalBsmtSF'] > 5000].index)
X = X.drop(X[(X['GrLivArea'] > 4000) & (X['SalePrice'] < 300000)].index)
X = X.drop(X[X['LowQualFinSF'] > 550].index)
X = X.drop(X[X['1stFlrSF'] > 4000].index)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)

# %% [markdown]
# Удаляем из датасета столбцы с высокой корреляцией и большим количеством пропусков.

# %%
columns_to_drop = list(col_corr_drop | col_missing_drop)
X.drop(columns_to_drop, axis=1, inplace=True)

# %% [markdown]
# Отделяем целевую переменную `SalePrice` от признаков, создаем копию тестового набора данных и разбиваем обучающую выборку на тренировочную и валидационную.

# %%
y = X.SalePrice.copy()
X.drop(['SalePrice'], axis=1, inplace=True)

X_test = test_data.copy()

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Числовые столбцы

# %% [markdown]
# Определяем числовые столбцы для дальнейшей обработки.

# %%
cat_num = list(set(X_train.select_dtypes(exclude='object').columns))

# %% [markdown]
# Пайплайн для обработки числовых признаков:
#
# 1. numerical_transform:
# - заменяет пропущенные значения на медиану;
# - применяет стандартизацию.

# %%
numerical_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %% [markdown]
# ## Категориальные столбцы

# %% [markdown]
# Определяем бинарные, порядковые и номинальные категориальные столбцы для дальнейшей обработки.

# %%
cat_col_transform = X_train.select_dtypes(include='object')
cat_ordinal = list({'LotShape', 'Utilities', 'LandSlope', 'ExterQual', 'ExterCond',
                    'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                    'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'FireplaceQu',
                    'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
                    'Fence', 'PoolQC'} - col_corr_drop - col_missing_drop)
cat_bin = list({'Street', 'Alley', 'CentralAir'} - col_corr_drop - col_missing_drop)
cat_nominal = list(set(cat_col_transform) - set(cat_ordinal) - set(cat_bin))

# %% [markdown]
# Создаем словари для кодирования бинарных и порядковых категориальных признаков в числовые значения.

# %%
CentralAir_map = {'Y': 1, 'N': 0}
Street_map = {'Pave': 1, 'Grvl': 0}
binary_mapping = [
    list(globals()[col + '_map'].keys())
    for col in cat_bin
]

LotShape_map = {'Reg': 3, 'IR1': 2, 'IR2': 1, 'IR3': 0}
Utilities_map = {'AllPub': 3, 'NoSewr': 2, 'NoSeWa': 1, 'ELO': 0}
LandSlope_map = {'Gtl': 2, 'Mod': 1, 'Sev': 0}
ExterQual_map = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
ExterCond_map = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
BsmtQual_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
BsmtCond_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
BsmtExposure_map = {'Gd': 4, 'Av': 3, 'Mn': 2, 'No': 1, 'NA': 0}
BsmtFinType1_map = {'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ': 2, 'Unf': 1, 'NA': 0}
BsmtFinType2_map = {'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ': 2, 'Unf': 1, 'NA': 0}
HeatingQC_map = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
KitchenQual_map = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
FireplaceQu_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
GarageFinish_map = {'Fin': 3, 'RFn': 2, 'Unf': 1, 'NA': 0}
GarageQual_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
GarageCond_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
PavedDrive_map = {'Y': 2, 'P': 1, 'N': 0}
Fence_map = {'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1, 'NA': 0}
ordinal_mapping = [
    list(globals()[col + '_map'].keys())
    for col in cat_ordinal
]

# %% [markdown]
# Пайплайны для обработки различных типов категориальных признаков:
#
# 1. nominal_transform — для номинативных (категориальных без порядка):
# - заменяет пропущенные значения на наиболее частые;
# - применяет OneHot-кодирование (каждая категория в отдельную колонку).
#
# 2. ordinal_transform — для порядковых признаков (с естественным порядком значений):
# - заменяет пропущенные значения на наиболее частые;
# - преобразует категории в числовые значения согласно заданному порядку (ordinal_mapping).
#
# 3. binary_transform — для бинарных признаков (две категории):
# - заменяет пропущенные значения на наиболее частые;
# - кодирует значения как 0 и 1 на основе заданных словарей (binary_mapping).

# %%
ordinal_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(categories=ordinal_mapping))
])

binary_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(categories=binary_mapping))
])

nominal_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# ## Пайплайн предобработки данных

# %% [markdown]
# Создаем препроцессор, который применяет разные трансформации к числовым, номинальным, порядковым и бинарным признакам.

# %%
preprocessor = ColumnTransformer([
    ('num', numerical_transform, cat_num),
    ('nom', nominal_transform, cat_nominal),
    ('ord', ordinal_transform, cat_ordinal),
    ('bin', binary_transform, cat_bin)
])

# %% [markdown]
# # Моделирование

# %% [markdown]
# Обучаем модель XGBoost с подбором гиперпараметров с помощью GridSearchCV и оцениваем её качество на валидационной выборке.

# %%
model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBRegressor())
])

param_grid = {
    'model__learning_rate' : [0.01, 0.1, 0.3, 0.5],
    'model__n_estimators' : [10, 50, 100, 200],
    'model__max_depth' : [3, 6, 9]
}

grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_root_mean_squared_error')
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_
preds = best_model.predict(X_valid)

print('MAE:', mean_absolute_error(y_valid, preds))
# Out:
# MAE: 14546.280498281787

# %%
preds_test = best_model.predict(X_test)

# %%
output = pd.DataFrame({'Id': X_test.index,
                       'SalePrice': preds_test})
output.to_csv('submission.csv', index=False)
